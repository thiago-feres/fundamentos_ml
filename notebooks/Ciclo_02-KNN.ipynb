# %% [markdown]
# # Ciclo 02: Aprendizado Supervisionado - Classificacao

# %% [markdown]
# ## 1.0 Import libraries

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## 1.1 Load dataset

# %%
df_raw = pd.read_csv('../dataset/train.csv')
df = df_raw.copy()

# %%
df.head()
# Out:
#    id_cliente  idade  saldo_atual  divida_atual  renda_anual  \
# 0        1767     21   278.172008       2577.05  24196.89636
# 1       11920     40   268.874152       2465.39  19227.37796
# 2        8910     36   446.643127       1055.29  42822.28223
# 3        4964     58   321.141267        703.05  51786.82600
# 4       10100     35   428.716114        891.29  44626.85346
#
#    valor_em_investimentos  taxa_utilizacao_credito  num_emprestimos  \
# 0              104.306544                31.038763                6
# 1               69.858778                36.917093                5
# 2              134.201478                34.561714                0
# 3              297.350067                31.493561                0
# 4              134.201478                28.028887                2
#
#    num_contas_bancarias  num_cartoes_credito  dias_atraso_dt_venc  \
# 0                     5                    7                   21
# ...

# %%
df.columns
# Out:
# Index(['id_cliente', 'idade', 'saldo_atual', 'divida_atual', 'renda_anual',
#        'valor_em_investimentos', 'taxa_utilizacao_credito', 'num_emprestimos',
#        'num_contas_bancarias', 'num_cartoes_credito', 'dias_atraso_dt_venc',
#        'num_pgtos_atrasados', 'num_consultas_credito', 'taxa_juros',
#        'investe_exterior', 'pessoa_polit_exp', 'limite_adicional'],
#       dtype='object')

# %% [markdown]
# ## 2.0 Selecao de features

# %%
features = ['idade', 'saldo_atual', 'divida_atual', 'renda_anual',
       'valor_em_investimentos', 'taxa_utilizacao_credito', 'num_emprestimos',
       'num_contas_bancarias', 'num_cartoes_credito', 'dias_atraso_dt_venc',
       'num_pgtos_atrasados', 'num_consultas_credito', 'taxa_juros']
label = 'limite_adicional'

x_train = df.loc[:, features]
y_train = df.loc[:, label]

# %%
x_train
# Out:
#       idade  saldo_atual  divida_atual   renda_anual  valor_em_investimentos  \
# 0        21   278.172008       2577.05   24196.89636              104.306544
# 1        40   268.874152       2465.39   19227.37796               69.858778
# 2        36   446.643127       1055.29   42822.28223              134.201478
# 3        58   321.141267        703.05   51786.82600              297.350067
# 4        35   428.716114        891.29   44626.85346              134.201478
# ...     ...          ...           ...           ...                     ...
# 9495     29   157.500279        157.98   32624.67754              237.739275
# 9496   1237   497.714090        805.43   49024.15700              118.883577
# 9497     47   306.557684       2250.42   42200.88978              134.201478
# 9498     42   209.870718        505.37   35391.32289              245.498881
# 9499     35   971.407512        851.22  106192.53216               78.140488
#
# ...

# %% [markdown]
# ## 3.0 Treinamento

# %%
# definicao de parametros do treinamento.
k = 7
knn_classifier = KNeighborsClassifier(n_neighbors = k)

# treinamento do algoritmo 
knn_classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred = knn_classifier.predict(x_train)
df = df.loc[:, ['id_cliente','limite_adicional']]
df['predicted'] = df['predicted'] = y_pred

# %%
df.head(50)
# Out:
#     id_cliente limite_adicional predicted
# 0         1767            Negar     Negar
# 1        11920            Negar     Negar
# 2         8910            Negar     Negar
# 3         4964            Negar     Negar
# 4        10100            Negar     Negar
# 5         2755            Negar     Negar
# 6         2859            Negar     Negar
# 7         5569            Negar     Negar
# 8        11674            Negar     Negar
# 9         5779            Negar     Negar
# 10        8283            Negar     Negar
# 11       10475            Negar     Negar
# 12        7208            Negar     Negar
# 13         248            Negar     Negar
# 14        6272            Negar     Negar
# 15        3995            Negar     Negar
# 16         840            Negar     Negar
# 17       10506            Negar     Negar
# 18       10552            Negar     Negar
# 19        5826            Negar     Negar
# 20        5911         Conceder     Negar
# ...
